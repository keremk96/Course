# %% [markdown]
# * This project is for repeating what I learned from online courses.
# * The data set from seaborn library which name is tips.
# * Data set give information about total bill and tip by categories that sex,smoker,day,time,size

# %% [markdown]
# # First Look to Data

# %%
import seaborn as sns
import numpy as np
import pandas as pd

tips = sns.load_dataset("tips")
df = tips.copy()

# %% [markdown]
# ## Structural Information of The Data Set

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# * Data types are Float,Categorical,Integer

# %%
df.shape
# Out:
# (244, 7)

# %% [markdown]
# * Data Frame consists of 7 features (columns) and 244 observations (rows)

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %% [markdown]
# * From above part, we can see mean and standart deviation of total_bill, tip and size

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# * Data Frame does not have any Null value

# %% [markdown]
# ## Categorical Variables' Summary

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
(df["sex"]
.value_counts()
.plot.barh()
.set_title("Sex Frequenncy"));

# %% [markdown]
# * We have 157 Male costumers, 87 Female costumers

# %%
df["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
(df["smoker"]
.value_counts()
.plot.barh()
.set_title("Smoker Frequency"));

# %% [markdown]
# * 151 costomers do not use smoke.However 93 costumers use smoke

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
(df["day"]
.value_counts()
.plot.barh()
.set_title("Day Frequency"));

# %% [markdown]
# * Restaurant has 19 costumers' table on Friday, 62 customers' table on Thursday, 76 customers' table on Sunday, 87 customers'table on Saturday

# %%
df["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
(df["time"]
.value_counts().
plot.barh()
.set_title("Time Frequency"));

# %% [markdown]
# * Restaurant has 68 customers at Lunch time, 176 customers at Dinner time

# %% [markdown]
# ## Numerical Variables' Summary

# %%
df_num = df.select_dtypes(include = ["float64","int64"])

# %%
df_num.head()
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4

# %%
df_num["total_bill"].describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %% [markdown]
# * total_bill has 244 observation
# * total_bill has a mean 19.79
# * total_bill has a standart deviation 8.90
# * total_bill has a minimum value 3.07
# * total_bill has a maximum value 50.81

# %%
df_num["tip"].describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %% [markdown]
# * tip has 244 observation
# * tip has a mean 2.99
# * tip has a standart deviation 1.38
# * tip has a minimum value 1
# * tip has a maximum value 10

# %%
df_num["size"].describe()
# Out:
# count    244.000000
# mean       2.569672
# std        0.951100
# min        1.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        6.000000
# Name: size, dtype: float64

# %% [markdown]
# * size has 244 observation
# * size has a mean 2.57
# * size has a standart deviation 0.95
# * size has a minimum value 1
# * size has a maximum value 6

# %% [markdown]
# # Data Visualization

# %%
sns.barplot(x = "day", y = "total_bill", data = df);

# %% [markdown]
# * Costumers spend more money onn Sunday than orher days
# * Costumers spend the least money on Friday

# %%
sns.barplot(x = "day", y = "tip", data = df);

# %% [markdown]
# * Costumers give more tip on Sunday than other days
# * Costumers give the least tip on Friday

# %%
sns.catplot(x = "day", y = "total_bill", data = df);

# %% [markdown]
# * We can see from above graph that dispersion of total_bill on days

# %%
sns.catplot(x = "day", y = "tip", data = df);

# %% [markdown]
# * We can see from above graph that dispersion of tip on days

# %%
sns.barplot(x = "sex", y = "total_bill", data = df);

# %% [markdown]
# * Males spend more money than Females

# %%
sns.barplot(x = "sex", y = "tip", data = df);

# %% [markdown]
# * Males gives more tip than Females

# %%
sns.catplot(x = "sex", y = "total_bill", data = df);

# %% [markdown]
# * We can see above graph that dispersion of total_bill by sex

# %%
sns.catplot(x = "sex", y = "tip", data = df);

# %% [markdown]
# * We can see above graph that dispersion of tip by sex

# %%
sns.barplot(x = "day", y = "total_bill", hue = "sex", data = df);

# %% [markdown]
# * All of  days Males spend more money than Women

# %%
sns.barplot(x = "time", y = "total_bill", hue = "smoker", data = df );

# %% [markdown]
# * At lunch time, smokers and non smokers almost spend the same money.However, at dinner time,smokers spends more money

# %%
sns.histplot(df.total_bill, kde = False);

# %%
sns.histplot(df.total_bill, bins = 10, kde = False);

# %%
sns.kdeplot(df.total_bill, fill = True);

# %% [markdown]
# * We can see it from last 3 graphs that, most of the income is between 10 dolars and 25 dolars

# %%
(sns
.FacetGrid(df,
              hue = "size",)
.map(sns.kdeplot, "total_bill", fill = True)
.add_legend()
);

# %% [markdown]
# * We can see above graph that density of tota_bill changes with size

# %%
sns.catplot(x = "size", y = "total_bill", hue = "day", kind = "point", data = df);

# %% [markdown]
# * We can see above graph that how size affects tota_bill on differrent days

# %%
sns.boxplot(x = df.total_bill);

# %% [markdown]
# * We can see above graph that total_billl that is higher than 40 dolars is outlier

# %%
sns.boxplot(x = "day", y = "total_bill", data = df);

# %% [markdown]
# * We can see above graph that outliers of total_bill by different days

# %%
sns.boxplot(x = "day", y = "total_bill", hue = "sex", data = df);

# %% [markdown]
# * We can see above graph that how sex affects total_bill by different days

# %%
sns.catplot(y = "total_bill", kind = "violin", data = df);

# %% [markdown]
# * Another representation of total_bill by using violin graph. Most data is between 10 and 25 dolars for total_bill

# %%
sns.catplot(x = "day", y = "total_bill", kind = "violin", data = df);

# %% [markdown]
# * We can see above graph that dispersion of toal_bill by days

# %%
sns.catplot(x = "day", y = "total_bill", hue = "sex", kind = "violin", data = df);

# %% [markdown]
# * We can see above graph that dispersion of toal_bill by days and sex

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = df);

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue = "time", style = "time", data = df);

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue = "day", style = "time", data = df);

# %% [markdown]
# * We can see above last 3 graphs that total_bill and tip has a linear relation

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue = "size", size = "size", data = df);

# %% [markdown]
# * We can see above graph that relation between total_bill and tip by changing size

# %%
import matplotlib.pyplot as plt

# %%
sns.lmplot(x = "total_bill", y = "tip", data = df);

# %% [markdown]
# * We can see above graph that total_bill and tip has a linear relation

# %%
sns.lmplot(x = "total_bill", y = "tip", hue = "smoker", data = df);

# %%
sns.lmplot(x = "total_bill", y = "tip", hue = "smoker", col = "time", row = "sex", data = df);

# %% [markdown]
# * We can see above last 2 graphs that how smoker affects total_bill and tip relation

# %%
sns.pairplot(df);

# %%
sns.pairplot(df, hue = "day");

# %%
sns.pairplot(df, kind = "reg");
